# %% [markdown]
# # AML 3104 MIDTERM EXAM
# # Students Performance in Exams
# Link to the dataset: https://www.kaggle.com/datasets/whenamancodes/students-performance-in-exams
# Group 5 Members:
# Dinampo, Vengie
# Discaya, Neil Patrick
# Harjreet, Kaur
# Padillo, Rubylyn
# Sittisakornsilp, Kriengkrai

# %% [markdown]
# # Problem Statement:
# The data set consists of the marks secured by the students in various subjects. The objective of this problem is to determine the overall success of student in all areas of math, reading and writing based on other features indicated in the dataset. Since there are three dependent variables involved as the output, think about how can you perform feature engineering to fit this into your model.

# %% [markdown]
# # Import all required Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly

# %% [markdown]
# # Reading the dataset exams.scv

# %%
data_url='https://raw.githubusercontent.com/vengie/student_performance/main/exams.csv'
data = pd.read_csv(data_url)
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
data.info() #checking the null and Dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.columns #showing the columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.isnull() #checking null values
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# 1                      False       False          False          False
# 2                      False       False          False          False
# 3                      False       False          False          False
# 4                      False       False          False          False
# ..                       ...         ...            ...            ...
# 995                    False       False          False          False
# 996                    False       False          False          False
# 997                    False       False          False          False
# 998                    False       False          False          False
# 999                    False       False          False          False
#
# [1000 rows x 8 columns]

# %%
data.isnull().sum() #summary of null values, if there is any
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.shape #dataset shape
# Out:
# (1000, 8)

# %%
print('Dataset Details:') #all dataset details Summary
print(f"Dataset has {data.shape[0]} rows and {data.shape[1]} columns")
print(f"Duplicates: {data.duplicated().sum()}")
print(f"Total Missing Values: {data.isna().sum().sum()}")
print(f"Number of rows with missing values: {data.isna().any(axis=1).sum()}")
# Out:
# Dataset Details:
# Dataset has 1000 rows and 8 columns
# Duplicates: 1
# Total Missing Values: 0
# Number of rows with missing values: 0

# %% [markdown]
# # Renaming columns and Label encoding

# %%
data = data.rename(columns={
    'race/ethnicity': 'race_ethnicity',
    'parental level of education': 'parent_education',
    'test preparation course': 'test_preparation_course',
    'math score': 'math_score',
    'reading score': 'reading_score',
    'writing score': 'writing_score',
    'overall success':'overall_success',
})
data.head()
# Out:
#    gender race_ethnicity    parent_education         lunch  \
# 0    male        group A         high school      standard
# 1  female        group D    some high school  free/reduced
# 2    male        group E        some college  free/reduced
# 3    male        group B         high school      standard
# 4    male        group E  associate's degree      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %% [markdown]
# # Exploratory Data Analysis (EDA) and Visualization

# %%
sns.countplot(x=data["race_ethnicity"], hue=data["gender"], palette="coolwarm")
plt.xlabel("Race/Ethnicity")
plt.ylabel("Frequency")
plt.show()

# %%
col = ['gender', 'race_ethnicity', 'parent_education', 'lunch', 'test_preparation_course']

for variable in col:
    var = data[variable]
    value = var.value_counts()

    plt.figure(figsize =(5,5))
    plt.bar(value.index, value, color='red')
    plt.xticks(value.index, value.index.values,rotation=45)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n{}".format(variable,value))
# Out:
# gender:
# male      517
# female    483
# Name: gender, dtype: int64
# race_ethnicity:
# group C    323
# group D    262
# group B    205
# group E    131
# group A     79
# Name: race_ethnicity, dtype: int64
# parent_education:
# some college          222
# associate's degree    203
# high school           202
# some high school      191
# bachelor's degree     112
# master's degree        70
# Name: parent_education, dtype: int64
# lunch:
# standard        652
# free/reduced    348
# Name: lunch, dtype: int64
# test_preparation_course:
# none         665
# completed    335
# Name: test_preparation_course, dtype: int64

# %%
corr = data.corr() #showing correlation using Heatmap
sns.heatmap(data=corr)
# Out:
# <ipython-input-13-66fda4cd926d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr() #showing correlation using Heatmap
# <Axes: >

# %% [markdown]
# based on the heatmap. If a student perform good on one subject he will perform also good on the other subjects

# %%
avg_education = data[["parent_education","math_score","reading_score","writing_score"]].groupby(["parent_education"]).mean().sort_values(by="math_score",ascending = False)
avg_education
# Out:
#                     math_score  reading_score  writing_score
# parent_education
# master's degree      71.585714      75.428571      75.885714
# bachelor's degree    71.491071      74.008929      74.410714
# associate's degree   69.536946      70.985222      70.113300
# some college         65.297297      68.045045      66.734234
# high school          65.207921      67.400990      64.846535
# some high school     60.701571      64.408377      62.539267

# %%
labels = data["parent_education"].value_counts().index
sizes = data["parent_education"].value_counts()
textprops = {"fontsize":20}
plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%', startangle=45, textprops =textprops)
plt.title('Parental level of Education in Pie chart',color = 'black',fontsize = 25)
plt.show()

# %% [markdown]
# # Calculating the average of all scores

# %%
col = data.loc[: , "math_score":"writing_score"]
col
# Out:
#      math_score  reading_score  writing_score
# 0            67             67             63
# 1            40             59             55
# 2            59             60             50
# 3            77             78             68
# 4            78             73             68
# ..          ...            ...            ...
# 995          73             70             65
# 996          85             91             92
# 997          32             35             41
# 998          73             74             82
# 999          65             60             62
#
# [1000 rows x 3 columns]

# %%
# adding new column named "overall success" which shows the average of three scores
data['overall_success'] = col.mean(axis=1)
data
# Out:
#      gender race_ethnicity    parent_education         lunch  \
# 0      male        group A         high school      standard
# 1    female        group D    some high school  free/reduced
# 2      male        group E        some college  free/reduced
# 3      male        group B         high school      standard
# 4      male        group E  associate's degree      standard
# ..      ...            ...                 ...           ...
# 995    male        group C         high school      standard
# 996    male        group D  associate's degree  free/reduced
# 997  female        group C    some high school  free/reduced
# 998  female        group C        some college      standard
# 999    male        group A        some college      standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 0                 completed          67             67             63
# 1                      none          40             59             55
# 2                      none          59             60             50
# 3                      none          77             78             68
# 4                 completed          78             73             68
# ..                      ...         ...            ...            ...
# 995                    none          73             70             65
# 996               completed          85             91             92
# 997                    none          32             35             41
# 998                    none          73             74             82
# 999               completed          65             60             62
#
#      overall_success
# 0          65.666667
# 1          51.333333
# 2          56.333333
# 3          74.333333
# 4          73.000000
# ..               ...
# 995        69.333333
# 996        89.333333
# 997        36.000000
# 998        76.333333
# 999        62.333333
#
# [1000 rows x 9 columns]

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()

data["gender_1"]=lb.fit_transform(data["gender"])
data["race_ethnicity_1"]=lb.fit_transform(data["race_ethnicity"])
data["test_preparation_course_1"]=lb.fit_transform(data["test_preparation_course"])
data["lunch_1"]=lb.fit_transform(data["lunch"])
data["parent_education_1"]=lb.fit_transform(data["parent_education"])

# %%
data.head()
# Out:
#    gender race_ethnicity    parent_education         lunch  \
# 0    male        group A         high school      standard
# 1  female        group D    some high school  free/reduced
# 2    male        group E        some college  free/reduced
# 3    male        group B         high school      standard
# 4    male        group E  associate's degree      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68
#
#    overall_success  gender_1  race_ethnicity_1  test_preparation_course_1  \
# 0        65.666667         1                 0                          0
# 1        51.333333         0                 3                          1
# 2        56.333333         1                 4                          1
# 3        74.333333         1                 1                          1
# 4        73.000000         1                 4                          0
#
#    lunch_1  parent_education_1
# 0        1                   2
# 1        0                   5
# 2        0                   4
# 3        1                   2
# 4        1                   0

# %% [markdown]
# # Dropping columns which are irrelevant

# %%
df=data.drop(["gender","race_ethnicity","test_preparation_course","lunch","parent_education"],axis=1)
df.head()
# Out:
#    math_score  reading_score  writing_score  overall_success  gender_1  \
# 0          67             67             63        65.666667         1
# 1          40             59             55        51.333333         0
# 2          59             60             50        56.333333         1
# 3          77             78             68        74.333333         1
# 4          78             73             68        73.000000         1
#
#    race_ethnicity_1  test_preparation_course_1  lunch_1  parent_education_1
# 0                 0                          0        1                   2
# 1                 3                          1        0                   5
# 2                 4                          1        0                   4
# 3                 1                          1        1                   2
# 4                 4                          0        1                   0

# %%
corr = df.corr() #showing correlation using Heatmap
sns.heatmap(data=corr)
# Out:
# <Axes: >

# %% [markdown]
# based on the heatmap above. we should use 'reading_score', 'math_score', 'writing_score', 'gender_num' and 'test_preparation_course_num' to build our model

# %% [markdown]
# # Determining dependent and independent variables

# %%
y = df["overall_success"]
X = df.drop(['overall_success'], axis=1)

# %%
y
# Out:
# 0      65.666667
# 1      51.333333
# 2      56.333333
# 3      74.333333
# 4      73.000000
#          ...
# 995    69.333333
# 996    89.333333
# 997    36.000000
# 998    76.333333
# 999    62.333333
# Name: overall_success, Length: 1000, dtype: float64

# %%
X = df.drop(['race_ethnicity_1', 'lunch_1', 'parent_education_1', 'overall_success'], axis=1)
X.head()
# Out:
#    math_score  reading_score  writing_score  gender_1  \
# 0          67             67             63         1
# 1          40             59             55         0
# 2          59             60             50         1
# 3          77             78             68         1
# 4          78             73             68         1
#
#    test_preparation_course_1
# 0                          0
# 1                          1
# 2                          1
# 3                          1
# 4                          0

# %% [markdown]
# # Splitting the Train and Test dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20,
                                                    random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Applying ML Algorithm 1 : DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dec_reg=DecisionTreeRegressor(max_depth=5)
dec_reg
dec_reg.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_pred_dec_reg=dec_reg.predict(X_test_scaled)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_dec_reg})
df
# Out:
#         Actual  Predicted
# 521  76.666667  77.714286
# 737  82.000000  83.615385
# 740  52.000000  54.523810
# 660  92.000000  87.259887
# 411  69.666667  70.519481
# ..         ...        ...
# 408  48.000000  50.736111
# 332  51.000000  50.736111
# 208  82.333333  82.333333
# 613  81.000000  81.240741
# 78   75.666667  77.733333
#
# [200 rows x 2 columns]

# %%
plt.scatter(y_test,y_pred_dec_reg)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dec_reg))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dec_reg))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dec_reg)))
r2_score = r2_score(y_test, y_pred_dec_reg, multioutput='uniform_average')
print('R2 SCORE:', r2_score)
# Out:
# Mean Absolute Error: 2.182780297142218
# Mean Squared Error: 7.088901537174849
# Root Mean Squared Error: 2.662499114962266
# R2 SCORE: 0.9680021797425077

# %% [markdown]
# Based on the results above, using decision tree regression will give an accurate prediction of the overall performance of the students.

# %% [markdown]
# #Effect of Learning rate on model performance

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam


model = Sequential()
model.add(Dense(64, input_dim=5, kernel_initializer='normal', activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1))  # Output layer for regression


# Print the model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 64)                384
#
#  dense_17 (Dense)            (None, 128)               8320
#
#  dense_18 (Dense)            (None, 256)               33024
#
#  dense_19 (Dense)            (None, 128)               32896
#
#  dense_20 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 74,753
# Trainable params: 74,753
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Compile Mode

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
import matplotlib.pyplot as plt

history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Plot the training and validation loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 25/25 [==============================] - 0s 6ms/step - loss: 221.0460 - mean_absolute_error: 12.0267 - val_loss: 229.5208 - val_mean_absolute_error: 12.2388
# Epoch 2/10
# 25/25 [==============================] - 0s 5ms/step - loss: 221.5647 - mean_absolute_error: 12.0551 - val_loss: 222.6039 - val_mean_absolute_error: 12.0866
# Epoch 3/10
# 25/25 [==============================] - 0s 4ms/step - loss: 212.6097 - mean_absolute_error: 11.7619 - val_loss: 240.8079 - val_mean_absolute_error: 12.4904
# Epoch 4/10
# 25/25 [==============================] - 0s 5ms/step - loss: 213.9036 - mean_absolute_error: 11.8785 - val_loss: 222.1667 - val_mean_absolute_error: 12.0813
# Epoch 5/10
# 25/25 [==============================] - 0s 5ms/step - loss: 211.5041 - mean_absolute_error: 11.7374 - val_loss: 222.0549 - val_mean_absolute_error: 12.0759
# Epoch 6/10
# 25/25 [==============================] - 0s 5ms/step - loss: 213.1597 - mean_absolute_error: 11.7995 - val_loss: 221.8279 - val_mean_absolute_error: 12.0762
# Epoch 7/10
# 25/25 [==============================] - 0s 5ms/step - loss: 229.9672 - mean_absolute_error: 12.2416 - val_loss: 221.5514 - val_mean_absolute_error: 12.0695
# Epoch 8/10
# 25/25 [==============================] - 0s 5ms/step - loss: 223.3272 - mean_absolute_error: 12.0150 - val_loss: 241.0154 - val_mean_absolute_error: 12.6835
# Epoch 9/10
# 25/25 [==============================] - 0s 5ms/step - loss: 229.6255 - mean_absolute_error: 12.2426 - val_loss: 249.6056 - val_mean_absolute_error: 12.6695
# Epoch 10/10
# 25/25 [==============================] - 0s 5ms/step - loss: 215.8391 - mean_absolute_error: 11.8216 - val_loss: 226.6142 - val_mean_absolute_error: 12.1727

# %% [markdown]
# #3. Create a y= f(x) where x is epochs and y is the training-validation loss difference as shown in the image (above)

# %%
def cal_difference(x, y):

    difference = [x_val - y_val for x_val, y_val in zip(x, y)]

    return difference

# Plot the difference between training and validation loss values against epochs

plt.plot(cal_difference(history.history['loss'],history.history['val_loss']) , label='Difference')

plt.xlabel('Epochs')

plt.ylabel('Difference')

plt.legend()

plt.show()

# %% [markdown]
# #5. Change learning_rate of your neural network to 1 and validate

# %%
model.compile(optimizer=Adam(learning_rate=1), loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
import matplotlib.pyplot as plt

history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Plot the training and validation loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 25/25 [==============================] - 2s 33ms/step - loss: 254.1751 - mean_absolute_error: 12.7268 - val_loss: 223.8315 - val_mean_absolute_error: 12.1093
# Epoch 2/10
# 25/25 [==============================] - 0s 12ms/step - loss: 216.0357 - mean_absolute_error: 11.8389 - val_loss: 222.2102 - val_mean_absolute_error: 12.0818
# Epoch 3/10
# 25/25 [==============================] - 0s 13ms/step - loss: 213.8987 - mean_absolute_error: 11.8052 - val_loss: 223.4444 - val_mean_absolute_error: 12.1168
# Epoch 4/10
# 25/25 [==============================] - 0s 12ms/step - loss: 234.7719 - mean_absolute_error: 12.3958 - val_loss: 259.3438 - val_mean_absolute_error: 13.2985
# Epoch 5/10
# 25/25 [==============================] - 0s 12ms/step - loss: 240.6250 - mean_absolute_error: 12.5520 - val_loss: 271.1082 - val_mean_absolute_error: 13.6444
# Epoch 6/10
# 25/25 [==============================] - 0s 12ms/step - loss: 222.1085 - mean_absolute_error: 11.9445 - val_loss: 232.3274 - val_mean_absolute_error: 12.3047
# Epoch 7/10
# 25/25 [==============================] - 0s 13ms/step - loss: 217.6660 - mean_absolute_error: 11.9833 - val_loss: 223.5105 - val_mean_absolute_error: 12.1016
# Epoch 8/10
# 25/25 [==============================] - 0s 10ms/step - loss: 218.1328 - mean_absolute_error: 11.9059 - val_loss: 224.8067 - val_mean_absolute_error: 12.1576
# Epoch 9/10
# 25/25 [==============================] - 0s 9ms/step - loss: 218.5647 - mean_absolute_error: 11.9364 - val_loss: 240.1852 - val_mean_absolute_error: 12.4768
# Epoch 10/10
# 25/25 [==============================] - 0s 9ms/step - loss: 216.9375 - mean_absolute_error: 11.9209 - val_loss: 230.4996 - val_mean_absolute_error: 12.3228

# %% [markdown]
# # Machine Learning Algorithm 2 : NEURAL NETWORK ARCHITECTURE#

# %%
#Import packages
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
from sklearn.model_selection import train_test_split

# %%
model = Sequential()
model.add(Dense(5, input_dim=5, kernel_initializer='normal', activation='relu'))
model.add(Dense(2670, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 2670)              16020
#
#  dense_2 (Dense)             (None, 1)                 2671
#
# =================================================================
# Total params: 18,721
# Trainable params: 18,721
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile Model**

# %%
model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['mean_absolute_error'])

# %%
import matplotlib.pyplot as plt

history = model.fit(X_train, y_train, epochs=10, batch_size=30, validation_data=(X_test, y_test))

# Plot the training and validation loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 27/27 [==============================] - 2s 25ms/step - loss: 2912.9585 - mean_absolute_error: 50.9387 - val_loss: 347.1190 - val_mean_absolute_error: 18.1028
# Epoch 2/10
# 27/27 [==============================] - 0s 9ms/step - loss: 98.0088 - mean_absolute_error: 8.1920 - val_loss: 23.3667 - val_mean_absolute_error: 4.5097
# Epoch 3/10
# 27/27 [==============================] - 0s 15ms/step - loss: 11.8108 - mean_absolute_error: 2.7434 - val_loss: 2.4863 - val_mean_absolute_error: 1.3318
# Epoch 4/10
# 27/27 [==============================] - 0s 13ms/step - loss: 1.6792 - mean_absolute_error: 1.0393 - val_loss: 1.2832 - val_mean_absolute_error: 0.9036
# Epoch 5/10
# 27/27 [==============================] - 0s 9ms/step - loss: 1.2903 - mean_absolute_error: 0.8992 - val_loss: 1.1460 - val_mean_absolute_error: 0.8487
# Epoch 6/10
# 27/27 [==============================] - 0s 10ms/step - loss: 1.2011 - mean_absolute_error: 0.8681 - val_loss: 1.1467 - val_mean_absolute_error: 0.8511
# Epoch 7/10
# 27/27 [==============================] - 0s 11ms/step - loss: 1.1611 - mean_absolute_error: 0.8546 - val_loss: 1.0754 - val_mean_absolute_error: 0.8238
# Epoch 8/10
# 27/27 [==============================] - 0s 16ms/step - loss: 1.1342 - mean_absolute_error: 0.8458 - val_loss: 1.0657 - val_mean_absolute_error: 0.8219
# Epoch 9/10
# 27/27 [==============================] - 0s 13ms/step - loss: 1.0889 - mean_absolute_error: 0.8272 - val_loss: 1.0112 - val_mean_absolute_error: 0.8005
# Epoch 10/10
# 27/27 [==============================] - 0s 14ms/step - loss: 1.0524 - mean_absolute_error: 0.8145 - val_loss: 1.0152 - val_mean_absolute_error: 0.8055

# %% [markdown]
# **Model Evaluation on the Test set**

# %%
predictions1 = model.predict(X_test)
predictions1
# Out:
# 7/7 [==============================] - 0s 4ms/step
# array([[77.548225],
#        [81.39936 ],
#        [52.666325],
#        [90.14887 ],
#        [70.56875 ],
#        [68.85396 ],
#        [96.391365],
#        [79.14626 ],
#        [79.04519 ],
#        [77.02533 ],
#        [60.424236],
#        [58.03362 ],
#        [57.892803],
#        [71.17699 ],
#        [36.467163],
#        [34.069492],
#        [81.08271 ],
#        [76.045586],
#        [74.5782  ],
#        [82.148346],
#        [53.52129 ],
#        [74.84288 ],
#        [70.57212 ],
#        [91.28105 ],
#        [66.193665],
#        [91.5568  ],
#        [77.008675],
#        [80.01788 ],
#        [71.813644],
#        [59.952217],
#        [80.539986],
#        [66.3897  ],
#        [46.79676 ],
#        [83.33333 ],
#        [75.35916 ],
#        [62.13259 ],
#        [71.214165],
#        [88.07365 ],
#        [67.10539 ],
#        [54.328823],
#        [59.24576 ],
#        [97.07406 ],
#        [47.58824 ],
#        [58.53148 ],
#        [43.492832],
#        [75.129456],
#        [64.14222 ],
#        [71.48383 ],
#        [66.25046 ],
#        [67.1027  ],
#        [63.553   ],
#        [52.714653],
#        [45.964054],
#        [69.76881 ],
#        [52.290028],
#        [79.71709 ],
#        [65.38815 ],
#        [86.24581 ],
#        [69.30149 ],
#        [77.342896],
#        [48.03797 ],
#        [54.346836],
#        [84.9346  ],
#        [63.35942 ],
#        [92.62978 ],
#        [86.06551 ],
#        [92.94177 ],
#        [62.402576],
#        [66.16141 ],
#        [60.177498],
#        [44.6909  ],
#        [75.02912 ],
#        [77.370316],
#        [64.31224 ],
#        [66.50473 ],
#        [62.973545],
#        [95.52592 ],
#        [82.99538 ],
#        [66.757515],
#        [64.336525],
#        [63.418808],
#        [61.421185],
#        [79.291115],
#        [47.394653],
#        [81.04145 ],
#        [43.43325 ],
#        [75.495995],
#        [71.18826 ],
#        [58.209244],
#        [64.491135],
#        [74.58379 ],
#        [56.82666 ],
#        [73.72444 ],
#        [63.22434 ],
#        [83.86896 ],
#        [70.96197 ],
#        [69.51951 ],
#        [55.63529 ],
#        [78.93951 ],
#        [92.38072 ],
#        [84.97177 ],
#        [48.593193],
#        [43.50447 ],
#        [76.854256],
#        [83.853584],
#        [46.779617],
#        [73.66232 ],
#        [84.365425],
#        [88.797005],
#        [70.94505 ],
#        [57.532253],
#        [66.59962 ],
#        [71.21078 ],
#        [96.40826 ],
#        [70.33531 ],
#        [69.90294 ],
#        [82.108955],
#        [49.752544],
#        [79.789566],
#        [55.85686 ],
#        [45.972748],
#        [79.423965],
#        [57.632477],
#        [65.357605],
#        [91.07852 ],
#        [46.787777],
#        [78.80249 ],
#        [66.97229 ],
#        [77.41228 ],
#        [80.87058 ],
#        [83.890274],
#        [65.77797 ],
#        [69.19625 ],
#        [69.04649 ],
#        [66.889336],
#        [59.26825 ],
#        [66.6941  ],
#        [57.366776],
#        [46.156265],
#        [62.81167 ],
#        [89.571884],
#        [67.21552 ],
#        [89.38378 ],
#        [98.59969 ],
#        [46.759468],
#        [66.31567 ],
#        [47.676807],
#        [33.770874],
#        [76.41501 ],
#        [75.9507  ],
#        [62.926586],
#        [90.17929 ],
#        [57.487385],
#        [78.92133 ],
#        [75.262535],
#        [42.422993],
#        [77.57388 ],
#        [77.81852 ],
#        [68.79664 ],
#        [75.942795],
#        [52.273132],
#        [79.62489 ],
#        [39.67144 ],
#        [75.93813 ],
#        [72.81274 ],
#        [52.94733 ],
#        [58.291103],
#        [30.025034],
#        [67.11541 ],
#        [69.83291 ],
#        [48.53799 ],
#        [48.535896],
#        [84.02288 ],
#        [63.639786],
#        [61.594757],
#        [79.30555 ],
#        [56.501102],
#        [84.68891 ],
#        [84.85663 ],
#        [71.84988 ],
#        [62.67091 ],
#        [42.726444],
#        [49.76923 ],
#        [74.395584],
#        [65.218376],
#        [62.033287],
#        [52.239086],
#        [63.692963],
#        [79.51078 ],
#        [63.02821 ],
#        [48.607643],
#        [33.87707 ],
#        [67.58916 ],
#        [66.1163  ],
#        [64.56947 ],
#        [48.470333],
#        [51.58304 ],
#        [82.35462 ],
#        [79.6383  ],
#        [74.773674]], dtype=float32)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions1))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions1))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions1)))
# Out:
# Mean Absolute Error: 0.8055193869272866
# Mean Squared Error: 1.0151661263999778
# Root Mean Squared Error: 1.007554527755187

# %% [markdown]
# **Model Improvement**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout

# %%
model2 = Sequential()
model2.add(Dense(5, input_dim=5, kernel_initializer='normal', activation='relu'))
model2.add(BatchNormalization())  # Add batch normalization layer
model2.add(Dense(2670, activation='relu'))
model2.add(BatchNormalization())  # Add batch normalization layer
# model2.add(Dropout(0.5))  # Add dropout layer with a dropout rate of 0.5
model2.add(Dense(1, activation='linear'))

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 5)                 30
#
#  batch_normalization (BatchN  (None, 5)                20
#  ormalization)
#
#  dense_4 (Dense)             (None, 2670)              16020
#
#  batch_normalization_1 (Batc  (None, 2670)             10680
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1)                 2671
#
# =================================================================
# Total params: 29,421
# Trainable params: 24,071
# Non-trainable params: 5,350
# _________________________________________________________________

# %%
model2.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['mean_absolute_error'])

# %%
import matplotlib.pyplot as plt

history = model2.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test))

# Plot the training and validation loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 13/13 [==============================] - 4s 68ms/step - loss: 4585.0356 - mean_absolute_error: 67.2499 - val_loss: 3940.3594 - val_mean_absolute_error: 61.3002
# Epoch 2/100
# 13/13 [==============================] - 0s 23ms/step - loss: 4409.6685 - mean_absolute_error: 66.2940 - val_loss: 4024.0327 - val_mean_absolute_error: 61.9198
# Epoch 3/100
# 13/13 [==============================] - 0s 25ms/step - loss: 4200.6392 - mean_absolute_error: 64.7449 - val_loss: 3673.8638 - val_mean_absolute_error: 59.1099
# Epoch 4/100
# 13/13 [==============================] - 0s 19ms/step - loss: 3850.6504 - mean_absolute_error: 62.0117 - val_loss: 3382.9126 - val_mean_absolute_error: 56.5631
# Epoch 5/100
# 13/13 [==============================] - 0s 22ms/step - loss: 3332.5972 - mean_absolute_error: 57.6108 - val_loss: 2870.9143 - val_mean_absolute_error: 51.8075
# Epoch 6/100
# 13/13 [==============================] - 0s 20ms/step - loss: 2645.0759 - mean_absolute_error: 51.3585 - val_loss: 2230.7397 - val_mean_absolute_error: 45.1675
# Epoch 7/100
# 13/13 [==============================] - 0s 20ms/step - loss: 1885.3551 - mean_absolute_error: 43.3257 - val_loss: 1499.7926 - val_mean_absolute_error: 36.2412
# Epoch 8/100
# 13/13 [==============================] - 0s 24ms/step - loss: 1162.9719 - mean_absolute_error: 33.9259 - val_loss: 845.4473 - val_mean_absolute_error: 26.1475
# Epoch 9/100
# 13/13 [==============================] - 0s 28ms/step - loss: 589.4687 - mean_absolute_error: 23.9801 - val_loss: 497.7307 - val_mean_absolute_error: 19.0425
# Epoch 10/100
# 13/13 [==============================] - 0s 19ms/step - loss: 228.2568 - mean_absolute_error: 14.7404 - val_loss: 258.2882 - val_mean_absolute_error: 13.3975
# Epoch 11/100
# 13/13 [==============================] - 0s 18ms/step - loss: 67.1812 - mean_absolute_error: 7.5673 - val_loss: 203.8875 - val_mean_absolute_error: 11.6077
# Epoch 12/100
# 13/13 [==============================] - 0s 19ms/step - loss: 18.1301 - mean_absolute_error: 3.4762 - val_loss: 176.5557 - val_mean_absolute_error: 10.7785
# Epoch 13/100
# 13/13 [==============================] - 0s 18ms/step - loss: 13.8821 - mean_absolute_error: 2.8567 - val_loss: 190.9965 - val_mean_absolute_error: 11.1922
# Epoch 14/100
# 13/13 [==============================] - 0s 27ms/step - loss: 3.3184 - mean_absolute_error: 1.4606 - val_loss: 185.3557 - val_mean_absolute_error: 11.0201
# Epoch 15/100
# 13/13 [==============================] - 0s 19ms/step - loss: 5.5466 - mean_absolute_error: 1.8470 - val_loss: 182.2030 - val_mean_absolute_error: 10.9370
# Epoch 16/100
# 13/13 [==============================] - 0s 20ms/step - loss: 6.2913 - mean_absolute_error: 2.0361 - val_loss: 177.7252 - val_mean_absolute_error: 10.7938
# Epoch 17/100
# 13/13 [==============================] - 0s 27ms/step - loss: 8.2335 - mean_absolute_error: 2.2812 - val_loss: 184.1457 - val_mean_absolute_error: 10.9794
# Epoch 18/100
# 13/13 [==============================] - 0s 25ms/step - loss: 6.8381 - mean_absolute_error: 2.1621 - val_loss: 165.7557 - val_mean_absolute_error: 10.3957
# Epoch 19/100
# 13/13 [==============================] - 0s 20ms/step - loss: 7.0022 - mean_absolute_error: 2.0727 - val_loss: 180.2464 - val_mean_absolute_error: 10.8562
# Epoch 20/100
# 13/13 [==============================] - 0s 34ms/step - loss: 6.2466 - mean_absolute_error: 1.9691 - val_loss: 163.8502 - val_mean_absolute_error: 10.3070
# Epoch 21/100
# 13/13 [==============================] - 0s 28ms/step - loss: 5.9667 - mean_absolute_error: 1.8429 - val_loss: 172.2471 - val_mean_absolute_error: 10.5699
# Epoch 22/100
# 13/13 [==============================] - 0s 27ms/step - loss: 8.5364 - mean_absolute_error: 2.3937 - val_loss: 180.0949 - val_mean_absolute_error: 10.8495
# Epoch 23/100
# 13/13 [==============================] - 0s 32ms/step - loss: 6.2156 - mean_absolute_error: 2.0170 - val_loss: 158.0667 - val_mean_absolute_error: 10.1234
# Epoch 24/100
# 13/13 [==============================] - 0s 32ms/step - loss: 7.6672 - mean_absolute_error: 2.3095 - val_loss: 152.6214 - val_mean_absolute_error: 9.9456
# Epoch 25/100
# 13/13 [==============================] - 0s 23ms/step - loss: 5.0348 - mean_absolute_error: 1.7678 - val_loss: 162.2746 - val_mean_absolute_error: 10.2841
# Epoch 26/100
# 13/13 [==============================] - 0s 27ms/step - loss: 8.0546 - mean_absolute_error: 2.3462 - val_loss: 154.9659 - val_mean_absolute_error: 10.0155
# Epoch 27/100
# 13/13 [==============================] - 0s 30ms/step - loss: 3.7181 - mean_absolute_error: 1.5426 - val_loss: 154.3008 - val_mean_absolute_error: 10.0370
# Epoch 28/100
# 13/13 [==============================] - 0s 22ms/step - loss: 5.6120 - mean_absolute_error: 1.9971 - val_loss: 129.7894 - val_mean_absolute_error: 9.1440
# Epoch 29/100
# 13/13 [==============================] - 0s 20ms/step - loss: 10.1714 - mean_absolute_error: 2.3230 - val_loss: 138.1655 - val_mean_absolute_error: 9.4865
# Epoch 30/100
# 13/13 [==============================] - 0s 24ms/step - loss: 5.6229 - mean_absolute_error: 1.7684 - val_loss: 127.4272 - val_mean_absolute_error: 9.1008
# Epoch 31/100
# 13/13 [==============================] - 0s 37ms/step - loss: 6.2959 - mean_absolute_error: 1.8768 - val_loss: 106.5584 - val_mean_absolute_error: 8.2091
# Epoch 32/100
# 13/13 [==============================] - 0s 30ms/step - loss: 5.0660 - mean_absolute_error: 1.7148 - val_loss: 116.9755 - val_mean_absolute_error: 8.6871
# Epoch 33/100
# 13/13 [==============================] - 0s 15ms/step - loss: 5.4920 - mean_absolute_error: 1.8972 - val_loss: 122.1147 - val_mean_absolute_error: 8.9430
# Epoch 34/100
# 13/13 [==============================] - 0s 12ms/step - loss: 4.3653 - mean_absolute_error: 1.6929 - val_loss: 128.5296 - val_mean_absolute_error: 9.2269
# Epoch 35/100
# 13/13 [==============================] - 0s 10ms/step - loss: 4.2280 - mean_absolute_error: 1.6904 - val_loss: 113.4067 - val_mean_absolute_error: 8.6322
# Epoch 36/100
# 13/13 [==============================] - 0s 11ms/step - loss: 3.8146 - mean_absolute_error: 1.5321 - val_loss: 103.4144 - val_mean_absolute_error: 8.2263
# Epoch 37/100
# 13/13 [==============================] - 0s 11ms/step - loss: 5.5623 - mean_absolute_error: 1.9146 - val_loss: 95.1423 - val_mean_absolute_error: 7.8773
# Epoch 38/100
# 13/13 [==============================] - 0s 12ms/step - loss: 4.1915 - mean_absolute_error: 1.5885 - val_loss: 100.4268 - val_mean_absolute_error: 8.1692
# Epoch 39/100
# 13/13 [==============================] - 0s 11ms/step - loss: 8.1017 - mean_absolute_error: 2.1580 - val_loss: 103.7218 - val_mean_absolute_error: 8.3314
# Epoch 40/100
# 13/13 [==============================] - 0s 11ms/step - loss: 8.9990 - mean_absolute_error: 2.1994 - val_loss: 60.5368 - val_mean_absolute_error: 6.2621
# Epoch 41/100
# 13/13 [==============================] - 0s 10ms/step - loss: 5.7517 - mean_absolute_error: 1.8424 - val_loss: 81.9727 - val_mean_absolute_error: 7.3870
# Epoch 42/100
# 13/13 [==============================] - 0s 13ms/step - loss: 5.0764 - mean_absolute_error: 1.7485 - val_loss: 100.9328 - val_mean_absolute_error: 8.2770
# Epoch 43/100
# 13/13 [==============================] - 0s 19ms/step - loss: 5.5530 - mean_absolute_error: 1.8590 - val_loss: 78.3477 - val_mean_absolute_error: 7.2394
# Epoch 44/100
# 13/13 [==============================] - 0s 16ms/step - loss: 7.6122 - mean_absolute_error: 1.9930 - val_loss: 58.0169 - val_mean_absolute_error: 6.1701
# Epoch 45/100
# 13/13 [==============================] - 0s 20ms/step - loss: 4.1230 - mean_absolute_error: 1.6639 - val_loss: 46.3007 - val_mean_absolute_error: 5.5281
# Epoch 46/100
# 13/13 [==============================] - 0s 18ms/step - loss: 4.5001 - mean_absolute_error: 1.7667 - val_loss: 53.9310 - val_mean_absolute_error: 6.0203
# Epoch 47/100
# 13/13 [==============================] - 0s 17ms/step - loss: 7.1323 - mean_absolute_error: 2.1519 - val_loss: 27.9861 - val_mean_absolute_error: 4.2490
# Epoch 48/100
# 13/13 [==============================] - 0s 11ms/step - loss: 6.6012 - mean_absolute_error: 2.1059 - val_loss: 19.4853 - val_mean_absolute_error: 3.4703
# Epoch 49/100
# 13/13 [==============================] - 0s 12ms/step - loss: 6.9662 - mean_absolute_error: 2.1741 - val_loss: 34.5059 - val_mean_absolute_error: 4.7777
# Epoch 50/100
# 13/13 [==============================] - 0s 12ms/step - loss: 5.1027 - mean_absolute_error: 1.8452 - val_loss: 35.0699 - val_mean_absolute_error: 4.8105
# Epoch 51/100
# 13/13 [==============================] - 0s 11ms/step - loss: 4.9077 - mean_absolute_error: 1.7165 - val_loss: 42.9622 - val_mean_absolute_error: 5.4715
# Epoch 52/100
# 13/13 [==============================] - 0s 12ms/step - loss: 5.6327 - mean_absolute_error: 1.8594 - val_loss: 33.2276 - val_mean_absolute_error: 4.7613
# Epoch 53/100
# 13/13 [==============================] - 0s 12ms/step - loss: 9.1168 - mean_absolute_error: 2.3769 - val_loss: 31.1367 - val_mean_absolute_error: 4.6117
# Epoch 54/100
# 13/13 [==============================] - 0s 13ms/step - loss: 6.2378 - mean_absolute_error: 1.9894 - val_loss: 8.1274 - val_mean_absolute_error: 2.1774
# Epoch 55/100
# 13/13 [==============================] - 0s 11ms/step - loss: 7.0944 - mean_absolute_error: 2.1352 - val_loss: 47.9355 - val_mean_absolute_error: 5.8610
# Epoch 56/100
# 13/13 [==============================] - 0s 13ms/step - loss: 11.4385 - mean_absolute_error: 2.6830 - val_loss: 69.2408 - val_mean_absolute_error: 7.0755
# Epoch 57/100
# 13/13 [==============================] - 0s 14ms/step - loss: 6.6415 - mean_absolute_error: 2.1857 - val_loss: 49.6520 - val_mean_absolute_error: 6.0179
# Epoch 58/100
# 13/13 [==============================] - 0s 15ms/step - loss: 6.8005 - mean_absolute_error: 2.0142 - val_loss: 22.1832 - val_mean_absolute_error: 3.8860
# Epoch 59/100
# 13/13 [==============================] - 0s 15ms/step - loss: 4.1335 - mean_absolute_error: 1.4135 - val_loss: 9.8040 - val_mean_absolute_error: 2.5148
# Epoch 60/100
# 13/13 [==============================] - 0s 15ms/step - loss: 6.9165 - mean_absolute_error: 2.1261 - val_loss: 29.7064 - val_mean_absolute_error: 4.6625
# Epoch 61/100
# 13/13 [==============================] - 0s 15ms/step - loss: 8.3635 - mean_absolute_error: 2.2408 - val_loss: 2.2433 - val_mean_absolute_error: 1.1632
# Epoch 62/100
# 13/13 [==============================] - 0s 15ms/step - loss: 5.6387 - mean_absolute_error: 1.9423 - val_loss: 4.2310 - val_mean_absolute_error: 1.4485
# Epoch 63/100
# 13/13 [==============================] - 0s 15ms/step - loss: 5.3948 - mean_absolute_error: 1.7869 - val_loss: 6.4728 - val_mean_absolute_error: 2.2949
# Epoch 64/100
# 13/13 [==============================] - 0s 15ms/step - loss: 9.1422 - mean_absolute_error: 2.3846 - val_loss: 14.4532 - val_mean_absolute_error: 2.4640
# Epoch 65/100
# 13/13 [==============================] - 0s 16ms/step - loss: 7.4958 - mean_absolute_error: 2.0823 - val_loss: 50.1385 - val_mean_absolute_error: 5.6259
# Epoch 66/100
# 13/13 [==============================] - 0s 15ms/step - loss: 8.5902 - mean_absolute_error: 2.2594 - val_loss: 37.9497 - val_mean_absolute_error: 4.9970
# Epoch 67/100
# 13/13 [==============================] - 0s 14ms/step - loss: 6.3757 - mean_absolute_error: 2.1378 - val_loss: 7.2224 - val_mean_absolute_error: 2.1580
# Epoch 68/100
# 13/13 [==============================] - 0s 14ms/step - loss: 5.6787 - mean_absolute_error: 1.9655 - val_loss: 9.4916 - val_mean_absolute_error: 2.5987
# Epoch 69/100
# 13/13 [==============================] - 0s 13ms/step - loss: 4.8886 - mean_absolute_error: 1.7879 - val_loss: 4.7301 - val_mean_absolute_error: 2.0204
# Epoch 70/100
# 13/13 [==============================] - 0s 15ms/step - loss: 4.6267 - mean_absolute_error: 1.7099 - val_loss: 7.9328 - val_mean_absolute_error: 2.6243
# Epoch 71/100
# 13/13 [==============================] - 0s 15ms/step - loss: 3.5624 - mean_absolute_error: 1.5776 - val_loss: 3.6611 - val_mean_absolute_error: 1.8165
# Epoch 72/100
# 13/13 [==============================] - 0s 14ms/step - loss: 7.5741 - mean_absolute_error: 2.1219 - val_loss: 23.2839 - val_mean_absolute_error: 4.0118
# Epoch 73/100
# 13/13 [==============================] - 0s 14ms/step - loss: 10.0114 - mean_absolute_error: 2.6096 - val_loss: 29.2894 - val_mean_absolute_error: 4.6720
# Epoch 74/100
# 13/13 [==============================] - 0s 15ms/step - loss: 5.3254 - mean_absolute_error: 1.8042 - val_loss: 3.6365 - val_mean_absolute_error: 1.3172
# Epoch 75/100
# 13/13 [==============================] - 0s 26ms/step - loss: 5.0663 - mean_absolute_error: 1.9386 - val_loss: 5.3562 - val_mean_absolute_error: 1.9359
# Epoch 76/100
# 13/13 [==============================] - 0s 19ms/step - loss: 3.5592 - mean_absolute_error: 1.5238 - val_loss: 4.7092 - val_mean_absolute_error: 1.8443
# Epoch 77/100
# 13/13 [==============================] - 0s 15ms/step - loss: 2.5797 - mean_absolute_error: 1.2557 - val_loss: 1.1542 - val_mean_absolute_error: 0.8853
# Epoch 78/100
# 13/13 [==============================] - 0s 17ms/step - loss: 3.4064 - mean_absolute_error: 1.4627 - val_loss: 0.4209 - val_mean_absolute_error: 0.5833
# Epoch 79/100
# 13/13 [==============================] - 0s 17ms/step - loss: 8.3850 - mean_absolute_error: 2.3280 - val_loss: 0.9699 - val_mean_absolute_error: 0.8442
# Epoch 80/100
# 13/13 [==============================] - 0s 18ms/step - loss: 5.1383 - mean_absolute_error: 1.7926 - val_loss: 0.7455 - val_mean_absolute_error: 0.7947
# Epoch 81/100
# 13/13 [==============================] - 0s 16ms/step - loss: 4.3605 - mean_absolute_error: 1.7367 - val_loss: 0.9555 - val_mean_absolute_error: 0.7455
# Epoch 82/100
# 13/13 [==============================] - 0s 16ms/step - loss: 12.1451 - mean_absolute_error: 2.7767 - val_loss: 0.5395 - val_mean_absolute_error: 0.6218
# Epoch 83/100
# 13/13 [==============================] - 0s 15ms/step - loss: 10.9057 - mean_absolute_error: 2.6567 - val_loss: 8.8519 - val_mean_absolute_error: 2.5310
# Epoch 84/100
# 13/13 [==============================] - 0s 21ms/step - loss: 5.7684 - mean_absolute_error: 1.7289 - val_loss: 8.2083 - val_mean_absolute_error: 2.1545
# Epoch 85/100
# 13/13 [==============================] - 0s 24ms/step - loss: 5.8045 - mean_absolute_error: 1.9843 - val_loss: 2.7671 - val_mean_absolute_error: 1.4289
# Epoch 86/100
# 13/13 [==============================] - 0s 22ms/step - loss: 3.4480 - mean_absolute_error: 1.5883 - val_loss: 4.2527 - val_mean_absolute_error: 1.4772
# Epoch 87/100
# 13/13 [==============================] - 0s 17ms/step - loss: 3.4082 - mean_absolute_error: 1.5246 - val_loss: 1.2801 - val_mean_absolute_error: 0.9123
# Epoch 88/100
# 13/13 [==============================] - 0s 16ms/step - loss: 6.4741 - mean_absolute_error: 2.1035 - val_loss: 2.5803 - val_mean_absolute_error: 1.2764
# Epoch 89/100
# 13/13 [==============================] - 0s 16ms/step - loss: 4.9605 - mean_absolute_error: 1.7988 - val_loss: 5.4928 - val_mean_absolute_error: 2.0204
# Epoch 90/100
# 13/13 [==============================] - 0s 14ms/step - loss: 3.6479 - mean_absolute_error: 1.4319 - val_loss: 0.9790 - val_mean_absolute_error: 0.7773
# Epoch 91/100
# 13/13 [==============================] - 0s 14ms/step - loss: 4.7869 - mean_absolute_error: 1.6716 - val_loss: 1.2145 - val_mean_absolute_error: 0.9637
# Epoch 92/100
# 13/13 [==============================] - 0s 15ms/step - loss: 5.7799 - mean_absolute_error: 1.8332 - val_loss: 3.1808 - val_mean_absolute_error: 1.5361
# Epoch 93/100
# 13/13 [==============================] - 0s 17ms/step - loss: 7.9615 - mean_absolute_error: 2.3735 - val_loss: 1.2268 - val_mean_absolute_error: 0.9289
# Epoch 94/100
# 13/13 [==============================] - 0s 14ms/step - loss: 5.1334 - mean_absolute_error: 1.7911 - val_loss: 0.7116 - val_mean_absolute_error: 0.6653
# Epoch 95/100
# 13/13 [==============================] - 0s 14ms/step - loss: 5.3349 - mean_absolute_error: 1.8076 - val_loss: 2.1234 - val_mean_absolute_error: 1.4375
# Epoch 96/100
# 13/13 [==============================] - 0s 15ms/step - loss: 3.2319 - mean_absolute_error: 1.3897 - val_loss: 4.2894 - val_mean_absolute_error: 1.8741
# Epoch 97/100
# 13/13 [==============================] - 0s 15ms/step - loss: 5.3139 - mean_absolute_error: 1.8559 - val_loss: 4.6167 - val_mean_absolute_error: 1.7306
# Epoch 98/100
# 13/13 [==============================] - 0s 16ms/step - loss: 5.2651 - mean_absolute_error: 1.8377 - val_loss: 2.4815 - val_mean_absolute_error: 1.3864
# Epoch 99/100
# 13/13 [==============================] - 0s 14ms/step - loss: 6.0250 - mean_absolute_error: 1.9400 - val_loss: 14.1312 - val_mean_absolute_error: 3.1660
# Epoch 100/100
# 13/13 [==============================] - 0s 11ms/step - loss: 5.0101 - mean_absolute_error: 1.7880 - val_loss: 0.8684 - val_mean_absolute_error: 0.8096

# %% [markdown]
# **Model Evaluation for the Improve Model on the Test set**

# %%
predictions2 = model2.predict(X_test)
predictions2
# Out:
# 7/7 [==============================] - 0s 3ms/step
# array([[75.35457 ],
#        [80.94712 ],
#        [51.66371 ],
#        [90.91717 ],
#        [68.37229 ],
#        [67.30293 ],
#        [96.656624],
#        [78.60186 ],
#        [77.99161 ],
#        [75.67436 ],
#        [58.401203],
#        [55.862267],
#        [58.01874 ],
#        [70.99832 ],
#        [36.94757 ],
#        [34.996483],
#        [81.04238 ],
#        [75.06252 ],
#        [73.00787 ],
#        [81.27851 ],
#        [52.368217],
#        [75.22073 ],
#        [70.039856],
#        [91.46    ],
#        [65.21061 ],
#        [92.115166],
#        [76.322426],
#        [78.61459 ],
#        [72.29165 ],
#        [57.725536],
#        [80.670876],
#        [64.6054  ],
#        [45.58023 ],
#        [83.64836 ],
#        [75.981636],
#        [61.30741 ],
#        [71.62238 ],
#        [87.68369 ],
#        [66.29404 ],
#        [55.26907 ],
#        [58.358116],
#        [96.884186],
#        [46.818516],
#        [58.230568],
#        [42.89941 ],
#        [74.44333 ],
#        [62.965076],
#        [71.1492  ],
#        [65.734314],
#        [66.35059 ],
#        [63.19835 ],
#        [53.672295],
#        [44.967903],
#        [69.18831 ],
#        [50.71145 ],
#        [79.882324],
#        [65.302826],
#        [86.402405],
#        [68.37298 ],
#        [76.408005],
#        [47.41209 ],
#        [53.293205],
#        [84.236725],
#        [63.53408 ],
#        [92.73248 ],
#        [86.343834],
#        [92.766266],
#        [64.02908 ],
#        [64.875984],
#        [60.288013],
#        [47.025166],
#        [74.76073 ],
#        [77.03159 ],
#        [64.152794],
#        [64.53173 ],
#        [63.088326],
#        [94.89626 ],
#        [82.57402 ],
#        [63.920963],
#        [63.87047 ],
#        [63.919697],
#        [61.573433],
#        [78.32829 ],
#        [47.178524],
#        [78.20684 ],
#        [42.059002],
#        [75.37478 ],
#        [70.164696],
#        [57.611332],
#        [63.316727],
#        [73.78818 ],
#        [56.966797],
#        [73.31015 ],
#        [63.70686 ],
#        [83.97377 ],
#        [69.2143  ],
#        [67.57665 ],
#        [56.18291 ],
#        [77.9707  ],
#        [91.1947  ],
#        [84.9011  ],
#        [47.903954],
#        [42.319477],
#        [76.37052 ],
#        [83.21581 ],
#        [45.603363],
#        [72.74364 ],
#        [84.79243 ],
#        [88.52472 ],
#        [69.74233 ],
#        [55.475952],
#        [66.20827 ],
#        [70.50475 ],
#        [96.24565 ],
#        [68.243416],
#        [68.01447 ],
#        [81.18221 ],
#        [48.794598],
#        [78.915825],
#        [53.84806 ],
#        [47.008976],
#        [78.70676 ],
#        [57.714813],
#        [63.2719  ],
#        [89.57848 ],
#        [46.47655 ],
#        [78.36905 ],
#        [65.47846 ],
#        [74.26667 ],
#        [79.9289  ],
#        [83.15113 ],
#        [64.2605  ],
#        [68.43522 ],
#        [68.39885 ],
#        [66.36628 ],
#        [58.74575 ],
#        [64.75407 ],
#        [56.81056 ],
#        [45.786827],
#        [59.87234 ],
#        [89.9327  ],
#        [66.095406],
#        [88.7396  ],
#        [98.591515],
#        [48.622505],
#        [66.37107 ],
#        [46.970375],
#        [32.98863 ],
#        [76.71791 ],
#        [73.220345],
#        [62.528778],
#        [88.604996],
#        [57.462513],
#        [79.59784 ],
#        [75.0661  ],
#        [40.524334],
#        [76.97582 ],
#        [77.83839 ],
#        [68.84118 ],
#        [75.671745],
#        [51.068962],
#        [78.29152 ],
#        [37.7573  ],
#        [75.59924 ],
#        [72.347496],
#        [53.266323],
#        [58.623886],
#        [30.075031],
#        [66.51856 ],
#        [69.80883 ],
#        [46.506886],
#        [50.528534],
#        [83.145226],
#        [64.27767 ],
#        [60.68843 ],
#        [78.298256],
#        [54.92378 ],
#        [84.205505],
#        [81.82724 ],
#        [71.44273 ],
#        [62.28142 ],
#        [42.277214],
#        [48.168686],
#        [74.398636],
#        [64.5162  ],
#        [59.941975],
#        [51.425877],
#        [63.080074],
#        [80.090904],
#        [60.585854],
#        [47.85464 ],
#        [33.666523],
#        [66.17025 ],
#        [66.281166],
#        [63.314457],
#        [47.75824 ],
#        [50.71412 ],
#        [81.21114 ],
#        [79.97108 ],
#        [74.50509 ]], dtype=float32)

# %% [markdown]
# **Model Evaluation of Metrics for Improved Model**

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions2))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions2))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions2)))
# Out:
# Mean Absolute Error: 0.8096155420939124
# Mean Squared Error: 0.8684269156355322
# Root Mean Squared Error: 0.9318942620466831

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# Based on the two algorithms in the Neural Network applied in our program to predict the overall performance of student on her scores in exams in 3 subjects, the first NN model is higher in terms of the Mean Absolute Error. The Mean Squared of the second NN algorithm is lower compared to the first NN algorithm, so it has better overall fit on the model. The Root Mean Squared Error (RMSE) of the second NN algo is lower like the Mean Absolute Error indicating improved accuracy. Overall the second NN algorithm results used/applied demonstrates more accuracy and improved performace compare to the first.
