# %% [markdown]
# # AML 3104 MIDTERM EXAM
# # Students Performance in Exams
# Link to the dataset: https://www.kaggle.com/datasets/whenamancodes/students-performance-in-exams
# Group 5 Members:
# Dinampo, Vengie
# Discaya, Neil Patrick
# Harjreet, Kaur
# Padillo, Rubylyn
# Sittisakornsilp, Kriengkrai

# %% [markdown]
# # Problem Statement:
# The data set consists of the marks secured by the students in various subjects. The objective of this problem is to determine the overall success of student in all areas of math, reading and writing based on other features indicated in the dataset. Since there are three dependent variables involved as the output, think about how can you perform feature engineering to fit this into your model.

# %% [markdown]
# # Import all required Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly

# %% [markdown]
# # Reading the dataset exams.scv

# %%
data_url='https://raw.githubusercontent.com/vengie/student_performance/main/exams.csv'
data = pd.read_csv(data_url)
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
data.info() #checking the null and Dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.columns #showing the columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data.isnull() #checking null values
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# 1                      False       False          False          False
# 2                      False       False          False          False
# 3                      False       False          False          False
# 4                      False       False          False          False
# ..                       ...         ...            ...            ...
# 995                    False       False          False          False
# 996                    False       False          False          False
# 997                    False       False          False          False
# 998                    False       False          False          False
# 999                    False       False          False          False
#
# [1000 rows x 8 columns]

# %%
data.isnull().sum() #summary of null values, if there is any
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.shape #dataset shape
# Out:
# (1000, 8)

# %%
print('Dataset Details:') #all dataset details Summary
print(f"Dataset has {data.shape[0]} rows and {data.shape[1]} columns")
print(f"Duplicates: {data.duplicated().sum()}")
print(f"Total Missing Values: {data.isna().sum().sum()}")
print(f"Number of rows with missing values: {data.isna().any(axis=1).sum()}")
# Out:
# Dataset Details:
# Dataset has 1000 rows and 8 columns
# Duplicates: 1
# Total Missing Values: 0
# Number of rows with missing values: 0

# %% [markdown]
# # Renaming columns and Label encoding

# %%
data = data.rename(columns={
    'race/ethnicity': 'race_ethnicity',
    'parental level of education': 'parent_education',
    'test preparation course': 'test_preparation_course',
    'math score': 'math_score',
    'reading score': 'reading_score',
    'writing score': 'writing_score',
    'overall success':'overall_success',
})
data.head()
# Out:
#    gender race_ethnicity    parent_education         lunch  \
# 0    male        group A         high school      standard
# 1  female        group D    some high school  free/reduced
# 2    male        group E        some college  free/reduced
# 3    male        group B         high school      standard
# 4    male        group E  associate's degree      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %% [markdown]
# # Exploratory Data Analysis (EDA) and Visualization

# %%
sns.countplot(x=data["race_ethnicity"], hue=data["gender"], palette="coolwarm")
plt.xlabel("Race/Ethnicity")
plt.ylabel("Frequency")
plt.show()

# %%
col = ['gender', 'race_ethnicity', 'parent_education', 'lunch', 'test_preparation_course']

for variable in col:
    var = data[variable]
    value = var.value_counts()

    plt.figure(figsize =(5,5))
    plt.bar(value.index, value, color='red')
    plt.xticks(value.index, value.index.values,rotation=45)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n{}".format(variable,value))
# Out:
# gender:
# male      517
# female    483
# Name: gender, dtype: int64
# race_ethnicity:
# group C    323
# group D    262
# group B    205
# group E    131
# group A     79
# Name: race_ethnicity, dtype: int64
# parent_education:
# some college          222
# associate's degree    203
# high school           202
# some high school      191
# bachelor's degree     112
# master's degree        70
# Name: parent_education, dtype: int64
# lunch:
# standard        652
# free/reduced    348
# Name: lunch, dtype: int64
# test_preparation_course:
# none         665
# completed    335
# Name: test_preparation_course, dtype: int64

# %%
corr = data.corr() #showing correlation using Heatmap
sns.heatmap(data=corr)
# Out:
# <ipython-input-92-66fda4cd926d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr() #showing correlation using Heatmap
# <Axes: >

# %% [markdown]
# based on the heatmap. If a student perform good on one subject he will perform also good on the other subjects

# %%
avg_education = data[["parent_education","math_score","reading_score","writing_score"]].groupby(["parent_education"]).mean().sort_values(by="math_score",ascending = False)
avg_education
# Out:
#                     math_score  reading_score  writing_score
# parent_education
# master's degree      71.585714      75.428571      75.885714
# bachelor's degree    71.491071      74.008929      74.410714
# associate's degree   69.536946      70.985222      70.113300
# some college         65.297297      68.045045      66.734234
# high school          65.207921      67.400990      64.846535
# some high school     60.701571      64.408377      62.539267

# %%
labels = data["parent_education"].value_counts().index
sizes = data["parent_education"].value_counts()
textprops = {"fontsize":20}
plt.figure(figsize = (8,8))
plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%', startangle=45, textprops =textprops)
plt.title('Parental level of Education in Pie chart',color = 'black',fontsize = 25)
plt.show()

# %% [markdown]
# # Calculating the average of all scores

# %%
col = data.loc[: , "math_score":"writing_score"]
col
# Out:
#      math_score  reading_score  writing_score
# 0            67             67             63
# 1            40             59             55
# 2            59             60             50
# 3            77             78             68
# 4            78             73             68
# ..          ...            ...            ...
# 995          73             70             65
# 996          85             91             92
# 997          32             35             41
# 998          73             74             82
# 999          65             60             62
#
# [1000 rows x 3 columns]

# %%
# adding new column named "overall success" which shows the average of three scores
data['overall_success'] = col.mean(axis=1)
data
# Out:
#      gender race_ethnicity    parent_education         lunch  \
# 0      male        group A         high school      standard
# 1    female        group D    some high school  free/reduced
# 2      male        group E        some college  free/reduced
# 3      male        group B         high school      standard
# 4      male        group E  associate's degree      standard
# ..      ...            ...                 ...           ...
# 995    male        group C         high school      standard
# 996    male        group D  associate's degree  free/reduced
# 997  female        group C    some high school  free/reduced
# 998  female        group C        some college      standard
# 999    male        group A        some college      standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 0                 completed          67             67             63
# 1                      none          40             59             55
# 2                      none          59             60             50
# 3                      none          77             78             68
# 4                 completed          78             73             68
# ..                      ...         ...            ...            ...
# 995                    none          73             70             65
# 996               completed          85             91             92
# 997                    none          32             35             41
# 998                    none          73             74             82
# 999               completed          65             60             62
#
#      overall_success
# 0          65.666667
# 1          51.333333
# 2          56.333333
# 3          74.333333
# 4          73.000000
# ..               ...
# 995        69.333333
# 996        89.333333
# 997        36.000000
# 998        76.333333
# 999        62.333333
#
# [1000 rows x 9 columns]

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()

data["gender_1"]=lb.fit_transform(data["gender"])
data["race_ethnicity_1"]=lb.fit_transform(data["race_ethnicity"])
data["test_preparation_course_1"]=lb.fit_transform(data["test_preparation_course"])
data["lunch_1"]=lb.fit_transform(data["lunch"])
data["parent_education_1"]=lb.fit_transform(data["parent_education"])

# %%
data.head()
# Out:
#    gender race_ethnicity    parent_education         lunch  \
# 0    male        group A         high school      standard
# 1  female        group D    some high school  free/reduced
# 2    male        group E        some college  free/reduced
# 3    male        group B         high school      standard
# 4    male        group E  associate's degree      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68
#
#    overall_success  gender_1  race_ethnicity_1  test_preparation_course_1  \
# 0        65.666667         1                 0                          0
# 1        51.333333         0                 3                          1
# 2        56.333333         1                 4                          1
# 3        74.333333         1                 1                          1
# 4        73.000000         1                 4                          0
#
#    lunch_1  parent_education_1
# 0        1                   2
# 1        0                   5
# 2        0                   4
# 3        1                   2
# 4        1                   0

# %% [markdown]
# # Dropping columns which are irrelevant

# %%
df=data.drop(["gender","race_ethnicity","test_preparation_course","lunch","parent_education"],axis=1)
df.head()
# Out:
#    math_score  reading_score  writing_score  overall_success  gender_1  \
# 0          67             67             63        65.666667         1
# 1          40             59             55        51.333333         0
# 2          59             60             50        56.333333         1
# 3          77             78             68        74.333333         1
# 4          78             73             68        73.000000         1
#
#    race_ethnicity_1  test_preparation_course_1  lunch_1  parent_education_1
# 0                 0                          0        1                   2
# 1                 3                          1        0                   5
# 2                 4                          1        0                   4
# 3                 1                          1        1                   2
# 4                 4                          0        1                   0

# %%
corr = df.corr() #showing correlation using Heatmap
sns.heatmap(data=corr)
# Out:
# <Axes: >

# %% [markdown]
# based on the heatmap above. we should use 'reading_score', 'math_score', 'writing_score', 'gender_num' and 'test_preparation_course_num' to build our model

# %% [markdown]
# # Determining dependent and independent variables

# %%
y = df["overall_success"]
X = df.drop(['overall_success'], axis=1)

# %%
y
# Out:
# 0      65.666667
# 1      51.333333
# 2      56.333333
# 3      74.333333
# 4      73.000000
#          ...
# 995    69.333333
# 996    89.333333
# 997    36.000000
# 998    76.333333
# 999    62.333333
# Name: overall_success, Length: 1000, dtype: float64

# %%
X = df.drop(['race_ethnicity_1', 'lunch_1', 'parent_education_1', 'overall_success'], axis=1)
X.head()
# Out:
#    math_score  reading_score  writing_score  gender_1  \
# 0          67             67             63         1
# 1          40             59             55         0
# 2          59             60             50         1
# 3          77             78             68         1
# 4          78             73             68         1
#
#    test_preparation_course_1
# 0                          0
# 1                          1
# 2                          1
# 3                          1
# 4                          0

# %% [markdown]
# # Splitting the Train and Test dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20,
                                                    random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Applying ML Algorithm 1 : DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dec_reg=DecisionTreeRegressor(max_depth=5)
dec_reg
dec_reg.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_pred_dec_reg=dec_reg.predict(X_test_scaled)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_dec_reg})
df
# Out:
#         Actual  Predicted
# 521  76.666667  77.714286
# 737  82.000000  83.615385
# 740  52.000000  54.523810
# 660  92.000000  87.259887
# 411  69.666667  70.519481
# ..         ...        ...
# 408  48.000000  50.736111
# 332  51.000000  50.736111
# 208  82.333333  82.333333
# 613  81.000000  81.240741
# 78   75.666667  77.733333
#
# [200 rows x 2 columns]

# %%
plt.scatter(y_test,y_pred_dec_reg)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dec_reg))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dec_reg))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dec_reg)))
r2_score = r2_score(y_test, y_pred_dec_reg, multioutput='uniform_average')
print('R2 SCORE:', r2_score)
# Out:
# Mean Absolute Error: 2.182780297142218
# Mean Squared Error: 7.0889015371748485
# Root Mean Squared Error: 2.662499114962266
# R2 SCORE: 0.9680021797425077

# %% [markdown]
# Based on the results above, using decision tree regression will give an accurate prediction of the overall performance of the students.

# %% [markdown]
# # Machine Learning Algorithm 2 : NEURAL NETWORK ARCHITECTURE#

# %%
#Import packages
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
from sklearn.model_selection import train_test_split

# %%
model = Sequential()
model.add(Dense(5, input_dim=5, kernel_initializer='normal', activation='relu'))
model.add(Dense(2670, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 5)                 30
#
#  dense_10 (Dense)            (None, 2670)              16020
#
#  dense_11 (Dense)            (None, 1)                 2671
#
# =================================================================
# Total params: 18,721
# Trainable params: 18,721
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile Model**

# %%
model.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['mean_absolute_error'])

# %%
import matplotlib.pyplot as plt

history = model.fit(X_train, y_train, epochs=10, batch_size=30, validation_data=(X_test, y_test))

# Plot the training and validation loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 27/27 [==============================] - 1s 13ms/step - loss: 4068.5237 - mean_absolute_error: 62.2066 - val_loss: 2669.0793 - val_mean_absolute_error: 50.3941
# Epoch 2/10
# 27/27 [==============================] - 0s 6ms/step - loss: 809.9537 - mean_absolute_error: 23.0444 - val_loss: 158.8724 - val_mean_absolute_error: 12.3927
# Epoch 3/10
# 27/27 [==============================] - 0s 5ms/step - loss: 31.2781 - mean_absolute_error: 4.5282 - val_loss: 1.7280 - val_mean_absolute_error: 1.0864
# Epoch 4/10
# 27/27 [==============================] - 0s 6ms/step - loss: 3.0074 - mean_absolute_error: 1.4060 - val_loss: 2.4141 - val_mean_absolute_error: 1.2912
# Epoch 5/10
# 27/27 [==============================] - 0s 7ms/step - loss: 1.8329 - mean_absolute_error: 1.0698 - val_loss: 1.6131 - val_mean_absolute_error: 1.0525
# Epoch 6/10
# 27/27 [==============================] - 0s 8ms/step - loss: 1.6526 - mean_absolute_error: 1.0221 - val_loss: 1.5236 - val_mean_absolute_error: 1.0219
# Epoch 7/10
# 27/27 [==============================] - 0s 8ms/step - loss: 1.5809 - mean_absolute_error: 1.0006 - val_loss: 1.4980 - val_mean_absolute_error: 1.0161
# Epoch 8/10
# 27/27 [==============================] - 0s 9ms/step - loss: 1.5068 - mean_absolute_error: 0.9777 - val_loss: 1.3980 - val_mean_absolute_error: 0.9804
# Epoch 9/10
# 27/27 [==============================] - 0s 7ms/step - loss: 1.4466 - mean_absolute_error: 0.9560 - val_loss: 1.4411 - val_mean_absolute_error: 0.9987
# Epoch 10/10
# 27/27 [==============================] - 0s 7ms/step - loss: 1.3841 - mean_absolute_error: 0.9398 - val_loss: 1.2777 - val_mean_absolute_error: 0.9386

# %% [markdown]
# **Model Evaluation on the Test set**

# %%
predictions1 = model.predict(X_test)
predictions1
# Out:
# 7/7 [==============================] - 0s 4ms/step
# array([[77.22777 ],
#        [81.2871  ],
#        [52.93016 ],
#        [89.571724],
#        [70.54697 ],
#        [68.89512 ],
#        [96.201675],
#        [78.138084],
#        [79.430374],
#        [77.18115 ],
#        [60.94782 ],
#        [58.143368],
#        [58.22585 ],
#        [71.73664 ],
#        [37.373566],
#        [35.381912],
#        [81.098755],
#        [75.67037 ],
#        [74.82168 ],
#        [82.39413 ],
#        [53.96186 ],
#        [75.435135],
#        [70.28738 ],
#        [90.81907 ],
#        [66.429695],
#        [91.8412  ],
#        [76.78168 ],
#        [80.22298 ],
#        [71.854034],
#        [59.81127 ],
#        [79.84948 ],
#        [66.95341 ],
#        [46.452408],
#        [83.75187 ],
#        [75.47914 ],
#        [61.53466 ],
#        [71.458755],
#        [88.00688 ],
#        [67.261536],
#        [55.413963],
#        [59.479828],
#        [96.94819 ],
#        [48.33516 ],
#        [59.002228],
#        [44.275677],
#        [75.08654 ],
#        [64.44946 ],
#        [71.119225],
#        [66.22993 ],
#        [67.828186],
#        [64.04261 ],
#        [53.287758],
#        [45.81129 ],
#        [69.875984],
#        [52.383884],
#        [80.01436 ],
#        [65.76773 ],
#        [86.59105 ],
#        [68.736595],
#        [78.0174  ],
#        [48.42729 ],
#        [55.417767],
#        [84.92384 ],
#        [63.36072 ],
#        [91.912834],
#        [86.568695],
#        [92.75805 ],
#        [63.199257],
#        [65.6423  ],
#        [60.451733],
#        [45.053894],
#        [75.15304 ],
#        [77.58819 ],
#        [64.48382 ],
#        [66.6271  ],
#        [63.7873  ],
#        [95.5903  ],
#        [83.819885],
#        [66.29717 ],
#        [63.90526 ],
#        [64.12691 ],
#        [62.268284],
#        [79.50647 ],
#        [47.653374],
#        [79.92571 ],
#        [43.91775 ],
#        [74.827415],
#        [71.082146],
#        [58.82283 ],
#        [65.425316],
#        [74.81278 ],
#        [57.747086],
#        [74.029526],
#        [62.79788 ],
#        [83.62834 ],
#        [71.084114],
#        [70.05948 ],
#        [55.32473 ],
#        [79.09714 ],
#        [91.68771 ],
#        [84.64595 ],
#        [49.261223],
#        [43.213173],
#        [77.13553 ],
#        [82.83179 ],
#        [46.870182],
#        [73.82925 ],
#        [84.657166],
#        [88.3289  ],
#        [71.09327 ],
#        [57.430912],
#        [66.797386],
#        [71.718124],
#        [96.19244 ],
#        [70.70977 ],
#        [69.7912  ],
#        [81.76738 ],
#        [50.48775 ],
#        [78.91189 ],
#        [55.75181 ],
#        [46.60472 ],
#        [79.818756],
#        [58.000698],
#        [66.04817 ],
#        [90.405945],
#        [48.480778],
#        [78.62446 ],
#        [67.357864],
#        [76.766464],
#        [81.00395 ],
#        [83.371086],
#        [65.9106  ],
#        [69.86866 ],
#        [69.56552 ],
#        [66.59797 ],
#        [59.461773],
#        [66.49437 ],
#        [57.376064],
#        [46.89009 ],
#        [62.94944 ],
#        [89.812546],
#        [68.00063 ],
#        [88.89394 ],
#        [98.32441 ],
#        [46.616814],
#        [66.57865 ],
#        [49.08609 ],
#        [34.789494],
#        [75.96886 ],
#        [75.50028 ],
#        [63.259365],
#        [89.81298 ],
#        [57.04085 ],
#        [79.50375 ],
#        [74.990204],
#        [41.939274],
#        [78.01273 ],
#        [78.48566 ],
#        [68.920334],
#        [75.894875],
#        [52.393036],
#        [79.27723 ],
#        [40.03785 ],
#        [76.55192 ],
#        [73.1975  ],
#        [54.350853],
#        [59.57061 ],
#        [30.888205],
#        [67.65868 ],
#        [69.986   ],
#        [49.309155],
#        [49.284355],
#        [84.091995],
#        [63.725853],
#        [62.15645 ],
#        [79.65525 ],
#        [57.173416],
#        [84.43914 ],
#        [84.744644],
#        [71.67734 ],
#        [63.0318  ],
#        [43.9946  ],
#        [50.88713 ],
#        [75.185005],
#        [65.324615],
#        [61.612625],
#        [52.81994 ],
#        [63.540054],
#        [79.502   ],
#        [62.795795],
#        [49.409996],
#        [34.305527],
#        [66.92682 ],
#        [66.31491 ],
#        [64.559685],
#        [49.345963],
#        [52.869877],
#        [82.25211 ],
#        [79.414734],
#        [74.5169  ]], dtype=float32)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions1))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions1))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions1)))
# Out:
# Mean Absolute Error: 0.9385775788625083
# Mean Squared Error: 1.277676518215888
# Root Mean Squared Error: 1.1303435399098312

# %% [markdown]
# **Model Improvement**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout

# %%
model2 = Sequential()
model2.add(Dense(5, input_dim=5, kernel_initializer='normal', activation='relu'))
model2.add(BatchNormalization())  # Add batch normalization layer
model2.add(Dense(2670, activation='relu'))
model2.add(BatchNormalization())  # Add batch normalization layer
# model2.add(Dropout(0.5))  # Add dropout layer with a dropout rate of 0.5
model2.add(Dense(1, activation='linear'))

# %%
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 5)                 30
#
#  batch_normalization_2 (Batc  (None, 5)                20
#  hNormalization)
#
#  dense_13 (Dense)            (None, 2670)              16020
#
#  batch_normalization_3 (Batc  (None, 2670)             10680
#  hNormalization)
#
#  dense_14 (Dense)            (None, 1)                 2671
#
# =================================================================
# Total params: 29,421
# Trainable params: 24,071
# Non-trainable params: 5,350
# _________________________________________________________________

# %%
model2.compile(loss='mean_squared_error', optimizer='adam',
              metrics=['mean_absolute_error'])

# %%
import matplotlib.pyplot as plt

history = model2.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test))

# Plot the training and validation loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 32ms/step - loss: 4651.2905 - mean_absolute_error: 67.2430 - val_loss: 4513.9590 - val_mean_absolute_error: 65.5820
# Epoch 2/100
# 13/13 [==============================] - 0s 14ms/step - loss: 4400.1699 - mean_absolute_error: 66.0700 - val_loss: 4196.1216 - val_mean_absolute_error: 63.1710
# Epoch 3/100
# 13/13 [==============================] - 0s 15ms/step - loss: 4103.5747 - mean_absolute_error: 63.9211 - val_loss: 3744.8672 - val_mean_absolute_error: 59.5563
# Epoch 4/100
# 13/13 [==============================] - 0s 15ms/step - loss: 3646.0522 - mean_absolute_error: 60.2443 - val_loss: 3227.6270 - val_mean_absolute_error: 55.0567
# Epoch 5/100
# 13/13 [==============================] - 0s 14ms/step - loss: 3014.7441 - mean_absolute_error: 54.7684 - val_loss: 2595.5330 - val_mean_absolute_error: 48.9720
# Epoch 6/100
# 13/13 [==============================] - 0s 15ms/step - loss: 2269.6797 - mean_absolute_error: 47.4398 - val_loss: 1803.7301 - val_mean_absolute_error: 40.1691
# Epoch 7/100
# 13/13 [==============================] - 0s 14ms/step - loss: 1509.3086 - mean_absolute_error: 38.5638 - val_loss: 1187.0737 - val_mean_absolute_error: 31.5784
# Epoch 8/100
# 13/13 [==============================] - 0s 14ms/step - loss: 858.8937 - mean_absolute_error: 28.8808 - val_loss: 655.5504 - val_mean_absolute_error: 22.2996
# Epoch 9/100
# 13/13 [==============================] - 0s 14ms/step - loss: 399.3190 - mean_absolute_error: 19.1458 - val_loss: 342.4141 - val_mean_absolute_error: 15.6036
# Epoch 10/100
# 13/13 [==============================] - 0s 13ms/step - loss: 132.4664 - mean_absolute_error: 10.8250 - val_loss: 224.0769 - val_mean_absolute_error: 12.3688
# Epoch 11/100
# 13/13 [==============================] - 0s 12ms/step - loss: 30.7654 - mean_absolute_error: 4.9689 - val_loss: 190.2642 - val_mean_absolute_error: 11.1889
# Epoch 12/100
# 13/13 [==============================] - 0s 14ms/step - loss: 9.8556 - mean_absolute_error: 2.4123 - val_loss: 190.5921 - val_mean_absolute_error: 11.2057
# Epoch 13/100
# 13/13 [==============================] - 0s 13ms/step - loss: 8.3103 - mean_absolute_error: 1.8458 - val_loss: 185.6177 - val_mean_absolute_error: 11.0311
# Epoch 14/100
# 13/13 [==============================] - 0s 14ms/step - loss: 11.0483 - mean_absolute_error: 2.5352 - val_loss: 196.1922 - val_mean_absolute_error: 11.3449
# Epoch 15/100
# 13/13 [==============================] - 0s 14ms/step - loss: 10.0506 - mean_absolute_error: 2.5725 - val_loss: 183.5350 - val_mean_absolute_error: 10.9771
# Epoch 16/100
# 13/13 [==============================] - 0s 13ms/step - loss: 10.4340 - mean_absolute_error: 2.4462 - val_loss: 176.0877 - val_mean_absolute_error: 10.7734
# Epoch 17/100
# 13/13 [==============================] - 0s 15ms/step - loss: 10.6046 - mean_absolute_error: 2.7273 - val_loss: 189.0168 - val_mean_absolute_error: 11.1323
# Epoch 18/100
# 13/13 [==============================] - 0s 14ms/step - loss: 12.4361 - mean_absolute_error: 2.6089 - val_loss: 173.3473 - val_mean_absolute_error: 10.6937
# Epoch 19/100
# 13/13 [==============================] - 0s 13ms/step - loss: 6.5801 - mean_absolute_error: 1.8587 - val_loss: 177.6676 - val_mean_absolute_error: 10.8066
# Epoch 20/100
# 13/13 [==============================] - 0s 14ms/step - loss: 11.8020 - mean_absolute_error: 2.7316 - val_loss: 166.0078 - val_mean_absolute_error: 10.4645
# Epoch 21/100
# 13/13 [==============================] - 0s 12ms/step - loss: 7.3854 - mean_absolute_error: 1.9449 - val_loss: 155.2762 - val_mean_absolute_error: 10.0971
# Epoch 22/100
# 13/13 [==============================] - 0s 12ms/step - loss: 7.8038 - mean_absolute_error: 2.2240 - val_loss: 168.3689 - val_mean_absolute_error: 10.5331
# Epoch 23/100
# 13/13 [==============================] - 0s 14ms/step - loss: 7.0623 - mean_absolute_error: 2.1602 - val_loss: 166.5489 - val_mean_absolute_error: 10.4917
# Epoch 24/100
# 13/13 [==============================] - 0s 12ms/step - loss: 8.3940 - mean_absolute_error: 2.1220 - val_loss: 141.3215 - val_mean_absolute_error: 9.6369
# Epoch 25/100
# 13/13 [==============================] - 0s 13ms/step - loss: 7.5942 - mean_absolute_error: 2.1380 - val_loss: 151.6525 - val_mean_absolute_error: 10.0074
# Epoch 26/100
# 13/13 [==============================] - 0s 14ms/step - loss: 9.1369 - mean_absolute_error: 2.4968 - val_loss: 152.4465 - val_mean_absolute_error: 10.0334
# Epoch 27/100
# 13/13 [==============================] - 0s 13ms/step - loss: 7.3379 - mean_absolute_error: 2.2186 - val_loss: 138.9762 - val_mean_absolute_error: 9.5679
# Epoch 28/100
# 13/13 [==============================] - 0s 13ms/step - loss: 6.1770 - mean_absolute_error: 1.8320 - val_loss: 114.3215 - val_mean_absolute_error: 8.6233
# Epoch 29/100
# 13/13 [==============================] - 0s 13ms/step - loss: 10.0288 - mean_absolute_error: 2.4955 - val_loss: 141.7353 - val_mean_absolute_error: 9.6838
# Epoch 30/100
# 13/13 [==============================] - 0s 13ms/step - loss: 8.3556 - mean_absolute_error: 2.3209 - val_loss: 119.5183 - val_mean_absolute_error: 8.8432
# Epoch 31/100
# 13/13 [==============================] - 0s 11ms/step - loss: 4.0275 - mean_absolute_error: 1.5471 - val_loss: 111.1678 - val_mean_absolute_error: 8.5383
# Epoch 32/100
# 13/13 [==============================] - 0s 12ms/step - loss: 6.6371 - mean_absolute_error: 1.8711 - val_loss: 119.3454 - val_mean_absolute_error: 8.8513
# Epoch 33/100
# 13/13 [==============================] - 0s 12ms/step - loss: 8.0513 - mean_absolute_error: 2.3330 - val_loss: 115.3496 - val_mean_absolute_error: 8.7318
# Epoch 34/100
# 13/13 [==============================] - 0s 11ms/step - loss: 5.2041 - mean_absolute_error: 1.7368 - val_loss: 100.6777 - val_mean_absolute_error: 8.0571
# Epoch 35/100
# 13/13 [==============================] - 0s 13ms/step - loss: 9.5189 - mean_absolute_error: 2.1876 - val_loss: 94.9340 - val_mean_absolute_error: 7.8625
# Epoch 36/100
# 13/13 [==============================] - 0s 12ms/step - loss: 8.4663 - mean_absolute_error: 2.1230 - val_loss: 74.1684 - val_mean_absolute_error: 6.8554
# Epoch 37/100
# 13/13 [==============================] - 0s 14ms/step - loss: 7.0596 - mean_absolute_error: 2.0569 - val_loss: 109.5960 - val_mean_absolute_error: 8.5168
# Epoch 38/100
# 13/13 [==============================] - 0s 13ms/step - loss: 8.8169 - mean_absolute_error: 2.4722 - val_loss: 64.2171 - val_mean_absolute_error: 6.2751
# Epoch 39/100
# 13/13 [==============================] - 0s 12ms/step - loss: 6.7057 - mean_absolute_error: 2.0785 - val_loss: 76.1125 - val_mean_absolute_error: 6.9735
# Epoch 40/100
# 13/13 [==============================] - 0s 14ms/step - loss: 5.3994 - mean_absolute_error: 1.7624 - val_loss: 72.6528 - val_mean_absolute_error: 6.6835
# Epoch 41/100
# 13/13 [==============================] - 0s 15ms/step - loss: 4.8718 - mean_absolute_error: 1.6757 - val_loss: 56.6656 - val_mean_absolute_error: 5.8975
# Epoch 42/100
# 13/13 [==============================] - 0s 14ms/step - loss: 7.0024 - mean_absolute_error: 1.8710 - val_loss: 63.2138 - val_mean_absolute_error: 6.2881
# Epoch 43/100
# 13/13 [==============================] - 0s 13ms/step - loss: 6.8081 - mean_absolute_error: 2.0603 - val_loss: 77.3182 - val_mean_absolute_error: 7.0261
# Epoch 44/100
# 13/13 [==============================] - 0s 14ms/step - loss: 5.3032 - mean_absolute_error: 1.7873 - val_loss: 35.1127 - val_mean_absolute_error: 4.4677
# Epoch 45/100
# 13/13 [==============================] - 0s 20ms/step - loss: 5.1008 - mean_absolute_error: 1.7583 - val_loss: 44.0505 - val_mean_absolute_error: 5.1250
# Epoch 46/100
# 13/13 [==============================] - 0s 21ms/step - loss: 4.8265 - mean_absolute_error: 1.6893 - val_loss: 59.8293 - val_mean_absolute_error: 6.2579
# Epoch 47/100
# 13/13 [==============================] - 0s 18ms/step - loss: 9.8832 - mean_absolute_error: 2.5512 - val_loss: 21.9428 - val_mean_absolute_error: 3.3434
# Epoch 48/100
# 13/13 [==============================] - 0s 18ms/step - loss: 9.4485 - mean_absolute_error: 2.4856 - val_loss: 20.2947 - val_mean_absolute_error: 3.3026
# Epoch 49/100
# 13/13 [==============================] - 0s 18ms/step - loss: 5.6509 - mean_absolute_error: 1.9053 - val_loss: 31.6768 - val_mean_absolute_error: 4.3613
# Epoch 50/100
# 13/13 [==============================] - 0s 19ms/step - loss: 7.3445 - mean_absolute_error: 2.1522 - val_loss: 8.4540 - val_mean_absolute_error: 2.0524
# Epoch 51/100
# 13/13 [==============================] - 0s 22ms/step - loss: 5.7914 - mean_absolute_error: 1.8668 - val_loss: 17.1096 - val_mean_absolute_error: 2.9367
# Epoch 52/100
# 13/13 [==============================] - 0s 19ms/step - loss: 6.7085 - mean_absolute_error: 1.9383 - val_loss: 23.0653 - val_mean_absolute_error: 3.6985
# Epoch 53/100
# 13/13 [==============================] - 0s 21ms/step - loss: 15.0240 - mean_absolute_error: 3.2266 - val_loss: 37.9889 - val_mean_absolute_error: 5.0353
# Epoch 54/100
# 13/13 [==============================] - 0s 21ms/step - loss: 6.0070 - mean_absolute_error: 2.0306 - val_loss: 7.5115 - val_mean_absolute_error: 1.9224
# Epoch 55/100
# 13/13 [==============================] - 0s 18ms/step - loss: 6.3959 - mean_absolute_error: 1.6851 - val_loss: 5.8543 - val_mean_absolute_error: 1.7676
# Epoch 56/100
# 13/13 [==============================] - 0s 19ms/step - loss: 7.9821 - mean_absolute_error: 2.2998 - val_loss: 26.4395 - val_mean_absolute_error: 4.2283
# Epoch 57/100
# 13/13 [==============================] - 0s 17ms/step - loss: 8.3582 - mean_absolute_error: 2.2264 - val_loss: 6.5461 - val_mean_absolute_error: 1.8761
# Epoch 58/100
# 13/13 [==============================] - 0s 13ms/step - loss: 7.9709 - mean_absolute_error: 2.2248 - val_loss: 3.7865 - val_mean_absolute_error: 1.6937
# Epoch 59/100
# 13/13 [==============================] - 0s 14ms/step - loss: 13.1762 - mean_absolute_error: 2.9721 - val_loss: 18.0241 - val_mean_absolute_error: 3.5671
# Epoch 60/100
# 13/13 [==============================] - 0s 12ms/step - loss: 9.0609 - mean_absolute_error: 2.3794 - val_loss: 12.5759 - val_mean_absolute_error: 2.9842
# Epoch 61/100
# 13/13 [==============================] - 0s 12ms/step - loss: 5.3591 - mean_absolute_error: 1.7623 - val_loss: 2.2379 - val_mean_absolute_error: 1.1316
# Epoch 62/100
# 13/13 [==============================] - 0s 13ms/step - loss: 4.6237 - mean_absolute_error: 1.7189 - val_loss: 3.9247 - val_mean_absolute_error: 1.5695
# Epoch 63/100
# 13/13 [==============================] - 0s 13ms/step - loss: 12.9769 - mean_absolute_error: 2.8149 - val_loss: 26.7435 - val_mean_absolute_error: 4.5374
# Epoch 64/100
# 13/13 [==============================] - 0s 12ms/step - loss: 8.6056 - mean_absolute_error: 2.3985 - val_loss: 2.0535 - val_mean_absolute_error: 1.3770
# Epoch 65/100
# 13/13 [==============================] - 0s 13ms/step - loss: 9.1447 - mean_absolute_error: 2.4833 - val_loss: 4.2624 - val_mean_absolute_error: 1.8275
# Epoch 66/100
# 13/13 [==============================] - 0s 13ms/step - loss: 6.5976 - mean_absolute_error: 2.0648 - val_loss: 10.6935 - val_mean_absolute_error: 2.4908
# Epoch 67/100
# 13/13 [==============================] - 0s 13ms/step - loss: 6.1407 - mean_absolute_error: 1.9620 - val_loss: 23.0904 - val_mean_absolute_error: 4.0545
# Epoch 68/100
# 13/13 [==============================] - 0s 12ms/step - loss: 7.9986 - mean_absolute_error: 2.1955 - val_loss: 7.0695 - val_mean_absolute_error: 1.9558
# Epoch 69/100
# 13/13 [==============================] - 0s 13ms/step - loss: 18.9003 - mean_absolute_error: 3.5989 - val_loss: 17.3002 - val_mean_absolute_error: 3.5827
# Epoch 70/100
# 13/13 [==============================] - 0s 13ms/step - loss: 8.6426 - mean_absolute_error: 2.1700 - val_loss: 10.7924 - val_mean_absolute_error: 2.8956
# Epoch 71/100
# 13/13 [==============================] - 0s 14ms/step - loss: 8.2935 - mean_absolute_error: 2.2997 - val_loss: 7.8565 - val_mean_absolute_error: 2.4904
# Epoch 72/100
# 13/13 [==============================] - 0s 14ms/step - loss: 4.6861 - mean_absolute_error: 1.7505 - val_loss: 4.3891 - val_mean_absolute_error: 1.7673
# Epoch 73/100
# 13/13 [==============================] - 0s 13ms/step - loss: 4.8192 - mean_absolute_error: 1.7896 - val_loss: 1.3122 - val_mean_absolute_error: 0.9571
# Epoch 74/100
# 13/13 [==============================] - 0s 11ms/step - loss: 3.2769 - mean_absolute_error: 1.5392 - val_loss: 0.4850 - val_mean_absolute_error: 0.6016
# Epoch 75/100
# 13/13 [==============================] - 0s 14ms/step - loss: 6.8039 - mean_absolute_error: 2.1619 - val_loss: 2.7151 - val_mean_absolute_error: 1.4733
# Epoch 76/100
# 13/13 [==============================] - 0s 14ms/step - loss: 6.1875 - mean_absolute_error: 1.9582 - val_loss: 0.6009 - val_mean_absolute_error: 0.6116
# Epoch 77/100
# 13/13 [==============================] - 0s 12ms/step - loss: 8.2355 - mean_absolute_error: 2.3688 - val_loss: 1.6677 - val_mean_absolute_error: 1.0797
# Epoch 78/100
# 13/13 [==============================] - 0s 11ms/step - loss: 4.3810 - mean_absolute_error: 1.6254 - val_loss: 2.0458 - val_mean_absolute_error: 1.0978
# Epoch 79/100
# 13/13 [==============================] - 0s 13ms/step - loss: 4.6027 - mean_absolute_error: 1.6924 - val_loss: 8.9599 - val_mean_absolute_error: 2.5948
# Epoch 80/100
# 13/13 [==============================] - 0s 13ms/step - loss: 5.8561 - mean_absolute_error: 2.0677 - val_loss: 2.7286 - val_mean_absolute_error: 1.2687
# Epoch 81/100
# 13/13 [==============================] - 0s 13ms/step - loss: 5.3222 - mean_absolute_error: 1.8299 - val_loss: 4.9798 - val_mean_absolute_error: 1.9163
# Epoch 82/100
# 13/13 [==============================] - 0s 15ms/step - loss: 4.3125 - mean_absolute_error: 1.7206 - val_loss: 4.3015 - val_mean_absolute_error: 1.7133
# Epoch 83/100
# 13/13 [==============================] - 0s 12ms/step - loss: 7.7563 - mean_absolute_error: 2.2455 - val_loss: 0.7682 - val_mean_absolute_error: 0.8152
# Epoch 84/100
# 13/13 [==============================] - 0s 12ms/step - loss: 5.1617 - mean_absolute_error: 1.8769 - val_loss: 0.8019 - val_mean_absolute_error: 0.6987
# Epoch 85/100
# 13/13 [==============================] - 0s 13ms/step - loss: 5.5853 - mean_absolute_error: 1.8426 - val_loss: 1.1832 - val_mean_absolute_error: 0.9478
# Epoch 86/100
# 13/13 [==============================] - 0s 13ms/step - loss: 3.2326 - mean_absolute_error: 1.5452 - val_loss: 0.7049 - val_mean_absolute_error: 0.7538
# Epoch 87/100
# 13/13 [==============================] - 0s 15ms/step - loss: 12.3985 - mean_absolute_error: 2.8294 - val_loss: 23.0807 - val_mean_absolute_error: 4.3101
# Epoch 88/100
# 13/13 [==============================] - 0s 13ms/step - loss: 10.1599 - mean_absolute_error: 2.5023 - val_loss: 2.0951 - val_mean_absolute_error: 1.1716
# Epoch 89/100
# 13/13 [==============================] - 0s 13ms/step - loss: 4.6426 - mean_absolute_error: 1.6833 - val_loss: 12.5660 - val_mean_absolute_error: 3.1974
# Epoch 90/100
# 13/13 [==============================] - 0s 12ms/step - loss: 11.9597 - mean_absolute_error: 2.8685 - val_loss: 8.3843 - val_mean_absolute_error: 2.4563
# Epoch 91/100
# 13/13 [==============================] - 0s 14ms/step - loss: 4.9444 - mean_absolute_error: 1.8753 - val_loss: 1.7542 - val_mean_absolute_error: 0.9548
# Epoch 92/100
# 13/13 [==============================] - 0s 13ms/step - loss: 6.8130 - mean_absolute_error: 1.9787 - val_loss: 6.5421 - val_mean_absolute_error: 2.3012
# Epoch 93/100
# 13/13 [==============================] - 0s 15ms/step - loss: 7.3877 - mean_absolute_error: 2.2496 - val_loss: 0.6251 - val_mean_absolute_error: 0.5938
# Epoch 94/100
# 13/13 [==============================] - 0s 13ms/step - loss: 6.2950 - mean_absolute_error: 2.0222 - val_loss: 0.4908 - val_mean_absolute_error: 0.6272
# Epoch 95/100
# 13/13 [==============================] - 0s 13ms/step - loss: 4.5769 - mean_absolute_error: 1.6735 - val_loss: 5.3644 - val_mean_absolute_error: 2.0741
# Epoch 96/100
# 13/13 [==============================] - 0s 14ms/step - loss: 9.4333 - mean_absolute_error: 2.5710 - val_loss: 2.9797 - val_mean_absolute_error: 1.5234
# Epoch 97/100
# 13/13 [==============================] - 0s 14ms/step - loss: 5.5008 - mean_absolute_error: 1.9585 - val_loss: 0.5695 - val_mean_absolute_error: 0.5677
# Epoch 98/100
# 13/13 [==============================] - 0s 14ms/step - loss: 5.8263 - mean_absolute_error: 1.9090 - val_loss: 0.3079 - val_mean_absolute_error: 0.4909
# Epoch 99/100
# 13/13 [==============================] - 0s 14ms/step - loss: 4.1423 - mean_absolute_error: 1.6280 - val_loss: 9.6918 - val_mean_absolute_error: 2.7908
# Epoch 100/100
# 13/13 [==============================] - 0s 13ms/step - loss: 9.2403 - mean_absolute_error: 2.5063 - val_loss: 0.1602 - val_mean_absolute_error: 0.3628

# %% [markdown]
# **Model Evaluation for the Improve Model on the Test set**

# %%
predictions2 = model2.predict(X_test)
predictions2
# Out:
# 7/7 [==============================] - 0s 4ms/step
# array([[76.22682 ],
#        [81.523186],
#        [51.441597],
#        [91.75525 ],
#        [69.254715],
#        [67.71542 ],
#        [97.56226 ],
#        [79.27894 ],
#        [78.83291 ],
#        [76.12906 ],
#        [58.59386 ],
#        [55.95062 ],
#        [57.957813],
#        [71.52854 ],
#        [36.018543],
#        [33.71031 ],
#        [81.56504 ],
#        [75.48234 ],
#        [73.43135 ],
#        [81.90564 ],
#        [52.347397],
#        [75.973   ],
#        [70.67228 ],
#        [92.4074  ],
#        [65.83527 ],
#        [93.35208 ],
#        [76.773   ],
#        [79.16016 ],
#        [72.85595 ],
#        [58.060944],
#        [81.32016 ],
#        [65.228516],
#        [45.076447],
#        [84.4356  ],
#        [76.93577 ],
#        [61.8838  ],
#        [72.254364],
#        [90.27233 ],
#        [66.82483 ],
#        [55.406948],
#        [58.69251 ],
#        [97.86782 ],
#        [46.445267],
#        [58.546276],
#        [42.40125 ],
#        [74.86156 ],
#        [63.653126],
#        [71.551765],
#        [65.83626 ],
#        [66.80077 ],
#        [63.49616 ],
#        [53.60608 ],
#        [44.44518 ],
#        [69.61597 ],
#        [50.561424],
#        [80.62494 ],
#        [65.41542 ],
#        [88.7938  ],
#        [68.70547 ],
#        [77.06976 ],
#        [47.062504],
#        [53.261227],
#        [85.101814],
#        [63.994514],
#        [93.65981 ],
#        [87.22715 ],
#        [93.65973 ],
#        [64.660286],
#        [65.41781 ],
#        [60.469513],
#        [45.464687],
#        [75.26999 ],
#        [77.484116],
#        [64.72716 ],
#        [65.05453 ],
#        [63.6831  ],
#        [95.9989  ],
#        [85.14953 ],
#        [64.7419  ],
#        [63.99688 ],
#        [64.59502 ],
#        [62.26471 ],
#        [79.06165 ],
#        [46.934376],
#        [79.06705 ],
#        [41.4956  ],
#        [75.82217 ],
#        [70.672874],
#        [57.6267  ],
#        [64.11015 ],
#        [74.31717 ],
#        [57.027905],
#        [73.74179 ],
#        [64.141685],
#        [84.76423 ],
#        [69.68958 ],
#        [68.04129 ],
#        [56.001133],
#        [78.570946],
#        [92.3066  ],
#        [85.82189 ],
#        [47.657444],
#        [41.7847  ],
#        [76.79426 ],
#        [83.91123 ],
#        [45.160522],
#        [73.123436],
#        [85.75727 ],
#        [89.32879 ],
#        [70.05724 ],
#        [55.44598 ],
#        [66.63944 ],
#        [70.83816 ],
#        [97.227745],
#        [68.98112 ],
#        [68.53019 ],
#        [82.09674 ],
#        [48.45544 ],
#        [79.408356],
#        [53.95807 ],
#        [46.156307],
#        [79.44858 ],
#        [57.835964],
#        [64.01753 ],
#        [90.5593  ],
#        [46.314777],
#        [78.7906  ],
#        [66.10226 ],
#        [74.61876 ],
#        [80.61589 ],
#        [84.08962 ],
#        [64.966064],
#        [68.8699  ],
#        [68.8464  ],
#        [66.748924],
#        [59.280025],
#        [65.44367 ],
#        [57.04151 ],
#        [45.4556  ],
#        [60.4321  ],
#        [91.29491 ],
#        [66.3186  ],
#        [89.72348 ],
#        [99.19842 ],
#        [47.825592],
#        [67.687386],
#        [46.783916],
#        [31.88222 ],
#        [77.35272 ],
#        [73.775925],
#        [63.011616],
#        [89.62116 ],
#        [57.77067 ],
#        [80.45195 ],
#        [75.546684],
#        [40.024143],
#        [77.60295 ],
#        [79.37072 ],
#        [69.46766 ],
#        [76.14929 ],
#        [50.931892],
#        [78.93325 ],
#        [37.031258],
#        [76.19109 ],
#        [72.866745],
#        [53.049263],
#        [58.86845 ],
#        [28.857475],
#        [67.03863 ],
#        [70.21719 ],
#        [46.04318 ],
#        [49.59087 ],
#        [84.19442 ],
#        [64.86412 ],
#        [61.310543],
#        [78.9525  ],
#        [55.066277],
#        [85.153694],
#        [83.05176 ],
#        [71.921394],
#        [62.46463 ],
#        [41.823536],
#        [47.817635],
#        [75.06809 ],
#        [64.71956 ],
#        [60.452675],
#        [51.38689 ],
#        [63.58596 ],
#        [80.88026 ],
#        [61.069202],
#        [47.550526],
#        [32.695404],
#        [66.999374],
#        [67.027245],
#        [63.710346],
#        [47.48695 ],
#        [50.612408],
#        [82.04447 ],
#        [80.61469 ],
#        [74.98259 ]], dtype=float32)

# %% [markdown]
# **Model Evaluation of Metrics for Improved Model**

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions2))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions2))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions2)))
# Out:
# Mean Absolute Error: 0.3628256575266517
# Mean Squared Error: 0.16017865322256383
# Root Mean Squared Error: 0.4002232542251435

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# Based on the two algorithms in the Neural Network applied in our program to predict the overall performance of student on her scores in exams in 3 subjects, the first NN model is higher in terms of the Mean Absolute Error. The Mean Squared of the second NN algorithm is lower compared to the first NN algorithm, so it has better overall fit on the model. The Root Mean Squared Error (RMSE) of the second NN algo is lower like the Mean Absolute Error indicating improved accuracy. Overall the second NN algorithm results used/applied demonstrates more accuracy and improved performace compare to the first.
